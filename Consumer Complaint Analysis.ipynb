# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\utkri\Documents\Study\Datasets\Comcast_telecom_complaints_data.csv",parse_dates=['Date'])

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   datetime64[ns]
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 191.2+ KB

# %%
# to convert into date we can also do it in following way

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date_new']=pd.to_datetime(df['Date_month_year'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   datetime64[ns]
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
#  11  Date_new                     2224 non-null   datetime64[ns]
# ...

# %%
df.drop(['Date_new'],inplace=True,axis=1)

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
# there is predefined function dt.month() name

# %%
df['Month']=df['Date'].dt.month_name()

# %% [markdown]
# Doing above like this will add a new column in DataFrame after the last column.

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
# daily basis trend chart

# %% [markdown]
# If we apply <i> value_counts() </i> function, we can see what complaints had been filed in one particular day.

# %%
daily=df['Date'].value_counts()
daily
# Out:
# 2015-06-24    218
# 2015-06-23    190
# 2015-06-25     98
# 2015-06-26     55
# 2015-06-30     53
#              ...
# 2015-05-24      7
# 2015-05-02      7
# 2015-04-05      6
# 2015-04-11      5
# 2015-05-03      5
# Name: Date, Length: 91, dtype: int64

# %% [markdown]
# We need to convert it into dataframe.

# %%
daily=pd.DataFrame(daily).reset_index()

# %%
daily
# Out:
#         index  Date
# 0  2015-06-24   218
# 1  2015-06-23   190
# 2  2015-06-25    98
# 3  2015-06-26    55
# 4  2015-06-30    53
# ..        ...   ...
# 86 2015-05-24     7
# 87 2015-05-02     7
# 88 2015-04-05     6
# 89 2015-04-11     5
# 90 2015-05-03     5
#
# [91 rows x 2 columns]

# %% [markdown]
# Now daily is a datframe. But we need to change the index. Hence resetting the index above. <br/><br/> But still index is not pointing to original index of 0,1,2,3. Hence renaming the column.

# %%
daily.rename(columns={'index':'Date','Date':'Count'},inplace=True)

# %%
daily
# Out:
#          Date  Count
# 0  2015-06-24    218
# 1  2015-06-23    190
# 2  2015-06-25     98
# 3  2015-06-26     55
# 4  2015-06-30     53
# ..        ...    ...
# 86 2015-05-24      7
# 87 2015-05-02      7
# 88 2015-04-05      6
# 89 2015-04-11      5
# 90 2015-05-03      5
#
# [91 rows x 2 columns]

# %% [markdown]
# Now plotting the graph for above dataframe for analysis of daily complaint filing.

# %%
sns.lineplot(x="Date",y="Count",data=daily)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# We could also build the chart using pandas by default graph plotting method shown below.

# %%
daily.plot(x='Date',y='Count',kind='line')
plt.show()

# %% [markdown]
# Now plotting for monthly data.

# %%
df.groupby(by="Month").count()["Ticket #"]
# Out:
# Month
# April     545
# June     1280
# May       399
# Name: Ticket #, dtype: int64

# %% [markdown]
# Since we cannot directly visualize it. We have to convert it into dataframe.

# %%
month_df=pd.DataFrame(df.groupby(by="Month").count()["Ticket #"]).reset_index()

# %%
month_df
# Out:
#    Month  Ticket #
# 0  April       545
# 1   June      1280
# 2    May       399

# %%
sns.barplot(x="Month",y="Ticket #",data=month_df)
plt.show()

# %% [markdown]
# Next task is to provide the frequency of complaint types.

# %%
df['Customer Complaint'].value_counts()
# Out:
# Comcast                         83
# Comcast Internet                18
# Comcast Data Cap                17
# comcast                         13
# Data Caps                       11
#                                 ..
# Comcast Throttling Speeds        1
# Internet speed not disclosed     1
# COMPLAINT AGAINST COMCAST        1
# Billing problem                  1
# Video Throttling                 1
# Name: Customer Complaint, Length: 1841, dtype: int64

# %% [markdown]
# The problem with the above result is Python is treating <i> Comcast </i> and <i> comcast </i> same. Though we can convert it into lower string but there are sentences also which means the same meaning. Hence we need to do it by NLP. Selecting top 10 values only, to make graph more meaningful and readable.

# %%
df['Customer Complaint']=df['Customer Complaint'].apply(lambda x: str(x).lower())

# %%
df['Customer Complaint']
# Out:
# 0                           comcast cable internet speeds
# 1            payment disappear - service got disconnected
# 2                                       speed and service
# 3       comcast imposed a new usage cap of 300gb that ...
# 4              comcast not working and no service to boot
#                               ...
# 2219                                 service availability
# 2220           comcast monthly billing for returned modem
# 2221                              complaint about comcast
# 2222               extremely unsatisfied comcast customer
# 2223                 comcast, ypsilanti mi internet speed
# Name: Customer Complaint, Length: 2224, dtype: object

# %%
complaint_df= df['Customer Complaint'].value_counts()

# %%
complaint_df
# Out:
# comcast                                                102
# comcast data cap                                        30
# comcast internet                                        29
# comcast data caps                                       21
# comcast billing                                         18
#                                                       ...
# issues with comcast regarding service, billing, etc      1
# questionable internet slowdown                           1
# comcast's customer service is awful                      1
# fraudulent billing                                       1
# lied to about install costs                              1
# Name: Customer Complaint, Length: 1740, dtype: int64

# %% [markdown]
# Initially customer complaint was 1841, now after converting it into lower string it has been reduced to 1740 character only. Now making the table with only top 10 values, otherwise it would become very difficult to read.

# %%
complaint_df=df['Customer Complaint'].value_counts()[:10]

# %%
complaint_df
# Out:
# comcast                     102
# comcast data cap             30
# comcast internet             29
# comcast data caps            21
# comcast billing              18
# comcast service              15
# internet speed               15
# unfair billing practices     13
# data caps                    13
# data cap                     12
# Name: Customer Complaint, dtype: int64

# %%
complaint_df=pd.DataFrame(complaint_df).reset_index()

# %%
complaint_df
# Out:
#                       index  Customer Complaint
# 0                   comcast                 102
# 1          comcast data cap                  30
# 2          comcast internet                  29
# 3         comcast data caps                  21
# 4           comcast billing                  18
# 5           comcast service                  15
# 6            internet speed                  15
# 7  unfair billing practices                  13
# 8                 data caps                  13
# 9                  data cap                  12

# %% [markdown]
# We need to change the column names.

# %%
complaint_df.rename(columns={"index":"Complaint type","Customer Complaint":"No. of complaints"},inplace=True)

# %%
complaint_df
# Out:
#              Complaint type  No. of complaints
# 0                   comcast                102
# 1          comcast data cap                 30
# 2          comcast internet                 29
# 3         comcast data caps                 21
# 4           comcast billing                 18
# 5           comcast service                 15
# 6            internet speed                 15
# 7  unfair billing practices                 13
# 8                 data caps                 13
# 9                  data cap                 12

# %%
plt.figure(figsize=(10,7))
sns.barplot(x="Complaint type",y="No. of complaints",data=complaint_df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# For our next task, finding different isuues related to whether speed, services or other issues. We will use <i> str.contains() </i> function. Series.str.contains() function is used to test if pattern or regex is contained within a string of a Series or Index. The function return boolean Series or Index based on whether a given pattern or regex is contained within a string of a Series or Index.

# %% [markdown]
# <img src="i-1.png" height=300 width=500>

# %%
df[df['Customer Complaint'].str.contains("speed")].count()
# Out:
# Ticket #                       192
# Customer Complaint             192
# Date                           192
# Date_month_year                192
# Time                           192
# Received Via                   192
# City                           192
# State                          192
# Zip code                       192
# Status                         192
# Filing on Behalf of Someone    192
# Month                          192
# dtype: int64

# %%
internet_issue_1=df[df["Customer Complaint"].str.contains("network")].count()['Ticket #']

# %%
internet_issue_1
# Out:
# 2

# %%
internet_issue_2=df[df["Customer Complaint"].str.contains("speed")].count()['Ticket #']

# %%
internet_issue_3=df[df["Customer Complaint"].str.contains("data")].count()['Ticket #']

# %%
total_internet_issue=internet_issue_1+internet_issue_2+internet_issue_3

# %%
total_internet_issue
# Out:
# 413

# %%
billing_issue_1=df[df["Customer Complaint"].str.contains("billing")].count()['Ticket #']

# %%
billing_issue_1
# Out:
# 298

# %%
billing_issue_2=df[df["Customer Complaint"].str.contains("charges")].count()['Ticket #']

# %%
total_billing_issue=billing_issue_1+billing_issue_2

# %%
total_billing_issue
# Out:
# 375

# %% [markdown]
# We can perform this function in following two ways, with function. For serive issue we will do it like in this way.

# %%
def getcomp(word):
    x=df[df["Customer Complaint"].str.contains(word)].count()["Ticket #"]
    return x

# %%
service_issue_1=getcomp("service")

# %% [markdown]
# For service_issue_2 we will do it in following way, if we don't want to use <i> str.contains() </i> function of pandas.

# %%
def n_getcomp(word):
    count=0
    for x in df["Customer Complaint"]:
        if word in x:
            count=count+1
    return count

# %%
service_issue_2=n_getcomp("customer")

# %%
total_service_issue=service_issue_1+service_issue_2

# %%
total_service_issue
# Out:
# 584

# %%
total_billing_issue, total_internet_issue, total_service_issue
# Out:
# (375, 413, 584)

# %% [markdown]
# Now we will check for other issues.

# %%
#checking total number of rows
df.shape
# Out:
# (2224, 12)

# %% [markdown]
# Now we will check for other remaining issue as every row is associated with one issue. So subtracting the sum of total_billing_issue, total_internet_issue, total_service_issue from total issue will give the remaining issue.

# %%
other=2224-(total_billing_issue+total_internet_issue+total_service_issue)

# %%
other
# Out:
# 852

# %% [markdown]
# So among around network, internet and any other issue, other issue remains to be highest with 852 issues.

# %% [markdown]
# Next we have to create a new columnn of only two variables, <b> Open </b> and <b> Closed</b>, where open and pending is to be categorized as Open and Closed and Solved to be categorized as Closed.

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
df['newstatus']=["Open" if st=="Open" or st=="Pending" else "Close" for st in df["Status"]]

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint       Date  \
# 0   250635                      comcast cable internet speeds 2015-04-22
# 1   223441       payment disappear - service got disconnected 2015-04-08
# 2   242732                                  speed and service 2015-04-18
# 3   277946  comcast imposed a new usage cap of 300gb that ... 2015-05-07
# 4   307175         comcast not working and no service to boot 2015-05-26
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone  Month Name newstatus
# ...

# %% [markdown]
# Now we only have two status, Open and Close, as we can see in the last column.

# %%
df['newstatus'].unique()
# Out:
# array(['Close', 'Open'], dtype=object)

# %% [markdown]
# Next task is to provide the state wise status of complaint in a stacked bar chart.

# %%
df.groupby(by=["State","newstatus"]).size()
# Out:
# State          newstatus
# Alabama        Close        17
#                Open          9
# Arizona        Close        14
#                Open          6
# Arkansas       Close         6
#                             ..
# Virginia       Open         11
# Washington     Close        75
#                Open         23
# West Virginia  Close         8
#                Open          3
# Length: 77, dtype: int64

# %% [markdown]
# To get it in better readable form we will use <i> unstack </i> function.

# %%
state_complaint=df.groupby(by=["State","newstatus"]).size().unstack()

# %% [markdown]
# Difference b/w <i>size</i> and <i>count</i> is that <i>count</i> only counts non-NA values.

# %%
state_complaint
# Out:
# newstatus             Close  Open
# State
# Alabama                17.0   9.0
# Arizona                14.0   6.0
# Arkansas                6.0   NaN
# California            159.0  61.0
# Colorado               58.0  22.0
# Connecticut             9.0   3.0
# Delaware                8.0   4.0
# District Of Columbia   14.0   2.0
# District of Columbia    1.0   NaN
# Florida               201.0  39.0
# Georgia               208.0  80.0
# Illinois              135.0  29.0
# Indiana                50.0   9.0
# Iowa                    1.0   NaN
# Kansas                  1.0   1.0
# Kentucky                4.0   3.0
# Louisiana              12.0   1.0
# Maine                   3.0   2.0
# Maryland               63.0  15.0
# Massachusetts          50.0  11.0
# Michigan               92.0  23.0
# Minnesota              29.0   4.0
# Mississippi            23.0  16.0
# Missouri                3.0   1.0
# Montana                 1.0   NaN
# Nevada                  1.0   NaN
# ...

# %% [markdown]
# We now have to print stack bar chart. Rather than using sns.barplot() method we will use pandas inbuilt method for printing bar chart, as using sns.barplot() we have to take two variables.

# %%
state_complaint.plot.bar(stacked=True,figsize=(10,10))
plt.show()

# %% [markdown]
# From the graph it is clear that highest number of closed and unclosed cases are in Georgia.

# %% [markdown]
# Next task is to find out which state has maximum complaint.

# %%
df.groupby(by=["State"]).count()
# Out:
#                       Ticket #  Customer Complaint  Date  Date_month_year  \
# State
# Alabama                     26                  26    26               26
# Arizona                     20                  20    20               20
# Arkansas                     6                   6     6                6
# California                 220                 220   220              220
# Colorado                    80                  80    80               80
# Connecticut                 12                  12    12               12
# Delaware                    12                  12    12               12
# District Of Columbia        16                  16    16               16
# District of Columbia         1                   1     1                1
# Florida                    240                 240   240              240
# Georgia                    288                 288   288              288
# Illinois                   164                 164   164              164
# ...

# %% [markdown]
# Since we are only interested in no. of tickets, we will only use ticket and sort it in descending order with top 5 values,as it will better in reading graph.

# %%
df.groupby(by=["State"]).count()['Ticket #'].sort_values(ascending=False)[:5]
# Out:
# State
# Georgia       288
# Florida       240
# California    220
# Illinois      164
# Tennessee     143
# Name: Ticket #, dtype: int64

# %% [markdown]
# Next question is to find thee which state has highest percentage of unresolved complaints. Showing the database.

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      comcast cable internet speeds 2015-04-22
# 1      223441       payment disappear - service got disconnected 2015-04-08
# 2      242732                                  speed and service 2015-04-18
# 3      277946  comcast imposed a new usage cap of 300gb that ... 2015-05-07
# 4      307175         comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               service availability 2015-04-02
# 2220   318775         comcast monthly billing for returned modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             extremely unsatisfied comcast customer 2015-06-23
# 2223   363614               comcast, ypsilanti mi internet speed 2015-06-24
#
# ...

# %%
df.groupby(by=["State","newstatus"]).size().unstack().fillna(0)
# Out:
# newstatus             Close  Open
# State
# Alabama                17.0   9.0
# Arizona                14.0   6.0
# Arkansas                6.0   NaN
# California            159.0  61.0
# Colorado               58.0  22.0
# Connecticut             9.0   3.0
# Delaware                8.0   4.0
# District Of Columbia   14.0   2.0
# District of Columbia    1.0   NaN
# Florida               201.0  39.0
# Georgia               208.0  80.0
# Illinois              135.0  29.0
# Indiana                50.0   9.0
# Iowa                    1.0   NaN
# Kansas                  1.0   1.0
# Kentucky                4.0   3.0
# Louisiana              12.0   1.0
# Maine                   3.0   2.0
# Maryland               63.0  15.0
# Massachusetts          50.0  11.0
# Michigan               92.0  23.0
# Minnesota              29.0   4.0
# Mississippi            23.0  16.0
# Missouri                3.0   1.0
# Montana                 1.0   NaN
# Nevada                  1.0   NaN
# ...

# %% [markdown]
# Since we are only interested in unresolved complaints, we will use sort by Open.

# %%
unresolved_data=df.groupby(by=["State","newstatus"]).size().unstack().fillna(0).sort_values('Open',ascending=False)

# %% [markdown]
# Since we have to find the percentage.

# %%
unresolved_data['unresolved_incomplete_prct']=unresolved_data['Open']/unresolved_data['Open'].sum()*100

# %%
unresolved_data
# Out:
# newstatus             Close  Open  unresolved_incomplete_prct
# State
# Georgia               208.0  80.0                   15.473888
# California            159.0  61.0                   11.798839
# Tennessee              96.0  47.0                    9.090909
# Florida               201.0  39.0                    7.543520
# Illinois              135.0  29.0                    5.609284
# Washington             75.0  23.0                    4.448743
# Michigan               92.0  23.0                    4.448743
# Colorado               58.0  22.0                    4.255319
# Texas                  49.0  22.0                    4.255319
# Pennsylvania          110.0  20.0                    3.868472
# New Jersey             56.0  19.0                    3.675048
# Mississippi            23.0  16.0                    3.094778
# Maryland               63.0  15.0                    2.901354
# Oregon                 36.0  13.0                    2.514507
# ...

# %% [markdown]
# Next question is to find  the percentage of complaints resolved till date, which were received through the Internet and customer care calls.

# %%
resolved_data=df.groupby(by=["Received Via","newstatus"]).size().unstack()

# %%
resolved_data
# Out:
# newstatus           Close  Open
# Received Via
# Customer Care Call    864   255
# Internet              843   262

# %%
resolved_data["resolved"]=resolved_data["Close"]/resolved_data["Close"].sum()*100

# %%
resolved_data
# Out:
# newstatus           Close  Open   resolved
# Received Via
# Customer Care Call    864   255  50.615114
# Internet              843   262  49.384886

# %%
# end of project 3
